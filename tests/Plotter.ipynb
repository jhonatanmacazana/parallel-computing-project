# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from IPython.display import HTML, Image
from matplotlib import animation, rc
import matplotlib.pyplot as plt
rc('animation', html='html5')

# %%
    df = pd.read_csv('results-par.csv', header= None).T
    df
# Out:
#                0            1            2            3            4  \
# 0    5009.985079  6670.673955  5839.488974  8328.950291  5839.843527
# 1    5020.784389    -0.027297  1679.290228  5841.977742  1679.944252
# 2    8330.031250  5010.250794  7499.397691  4181.458673  9160.828866
# 3    4180.113043  2518.902167  8329.563916    -0.235111  8329.584635
# 4       1.120739   839.136169   839.246138   839.267498   840.269872
# 5    8340.125299  5839.785168  9156.867555  1681.562192  5010.512770
# 6    6669.685334  4180.122383  2520.745189  2520.073990  6669.159173
# 7      10.580572  8330.621205     0.948583  8339.575859    -0.395348
# 8    8350.282656  3350.275013  6670.876771  5849.024037  2521.147220
# 9    9157.045411  9160.305635  5009.687641  7499.711415  3349.853963
# 10   2519.927189  1679.263555    10.765667  5010.762985  5852.300869
# 11   6680.241971  7499.154391  4180.446420  4191.528243   850.174342
# 12     18.719383  6681.085119  5851.250820  9159.323019  9166.196559
# ...

# %%
df = pd.read_csv('results-seq.csv', header= None).T
i = 30
leg = []
plt.figure(figsize = (9,9))
y = df.iloc[i].values
plt.plot(y)
leg.append("x{}".format(i))
plt.legend(leg)

# %% [markdown]
# ##  Seq n0 =  30

# %%
df = pd.read_csv('results-par.csv', header= None).T
leg = []
t = np.arange(0,10.01,0.01)
plt.figure(figsize = (8,8))
for i in list(df.index)[5:20] :
    y = df.iloc[i].values
    plt.plot(y)
    leg.append("x{}".format(i))
plt.legend(leg)
plt.xlabel("time (s)")
plt.ylabel("X (m) ")

#plt.savefig('../docs/images/seq_n30.png')
# Out:
# Text(0, 0.5, 'X (m) ')

# %% [markdown]
# ## Seq n0=60

# %%
df = pd.read_csv('results-seq.csv', header= None).T
leg = []
t = np.arange(0,10.01,0.01)
plt.figure(figsize = (8,8))
for i in list(df.index)[25:40] :
    y = df.iloc[i].values
    plt.plot(t,y)
    leg.append("x{}".format(i))
plt.legend(leg)
plt.xlabel("time (s)")
plt.ylabel("X (m) ")

plt.savefig('../docs/images/seq_n60_30.png')

# %%
df = pd.read_csv('results-seq.csv', header= None).T
leg = []
t = np.arange(0,10.01,0.01)
plt.figure(figsize = (8,8))
for i in list(df.index)[55:70] :
    y = df.iloc[i].values
    plt.plot(t,y)
    leg.append("x{}".format(i))
plt.legend(leg)
plt.xlabel("time (s)")
plt.ylabel("X (m) ")

plt.savefig('../docs/images/seq_n60_60.png')
